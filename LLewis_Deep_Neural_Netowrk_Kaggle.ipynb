# %% [markdown]
# <a href="https://colab.research.google.com/github/LLewis/kaggle-deep-learning/blob/main/LLewis_Deep_Neural_Netowrk_Kaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Create a linear model accepting three input features
# sugars, fiber and protien
# producing one output calories
# using tensorflow and keras ?
# we would multiply each input to its connection weight and then add them all together.

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers

##Example 1
#create a newtork with 1 linera unit
model = keras.Sequential([
    layers.Dense(units=1, input_shape=[3]) #units=1 is output, input_shape are three featers or aka three dimensions of input
])

####Example 2
#calculating the linear weighted sum
#and generated a predicted value
import tensorflow as tf
import matplotlib.pyplot as plt

model = keras.Sequential([
    layers.Dense(1, input_shape=[1])
])
w, b = model.weights  #bias value not required here
print("Weights\n{}\n\nBias\n{}".format(w,b))

x = tf.linspace(-1.0, 1.0, 100)
y = model.predict(x)

plt.figure(dpi=100)
plt.plot(x, y, 'k')
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.xlabel("Input: x")
plt.ylabel("Target y")
w, b = model.weights # you could also use model.get_weights() here
plt.title("Weight: {:0.2f}\nBias: {:0.2f}".format(w[0][0], b[0]))
plt.show()
# Out:
# Weights
# <tf.Variable 'dense_70/kernel:0' shape=(1, 1) dtype=float32, numpy=array([[0.75632846]], dtype=float32)>
#
# Bias
# <tf.Variable 'dense_70/bias:0' shape=(1,) dtype=float32, numpy=array([0.], dtype=float32)>
# 4/4 [==============================] - 0s 2ms/step

# %%
#Deep Neural Networks
#ANN typically organize their neurons or units into layers
#When I collect the linear units that have a common set of inputs, I get a "dense" layer
#Each layer does some type of transformation, like
#the convolutional and recurrent layers - that transfom data by use of neurons or linear untis and have different connections type to neuron
#feature engineering layer, simple arithmetic layer ?
#Two dense layers - two layers with similiar features ?

# %% [markdown]
# Stacking Dense Layers
#
# Now that we have some nonlinearity, let's see how we can stack layers to get complex data transformations.
# An input layer, two hidden layers, and a final linear layer.
# A stack of dense layers makes a "fully-connected" network.
#
# The layers before the output layer are sometimes called hidden since we never see their outputs directly.
#
# Now, notice that the final (output) layer is a linear unit (meaning, no activation function). That makes this network appropriate to a regression task, where we are trying to predict some arbitrary numeric value. Other tasks (like classification) might require an activation function on the output.
#
# reference: https://www.kaggle.com/code/ryanholbrook/deep-neural-networks/tutorial
#
# The rectifier function has a graph that's a line with the negative part "rectified" to zero. Applying the function to the outputs of a neuron will put a bend in the data, moving us away from simple lines.
#
# When we attach the rectifier to a linear unit, we get a rectified linear unit or ReLU. (For this reason, it's common to call the rectifier function the "ReLU function".) Applying a ReLU activation to a linear unit means the output becomes max(0, w * x + b), which we might draw in a diagram like:

# %%
#creating deep neural networks -
# Build a sequential mnodel connecting together a list of layers in order
#from "first to last: the first layer gets the input and the last layer produces the output"
# Be sure to pass all the layers together in a list, like [layer, layer, layer, ...], instead of as separate arguments.
#To add an activation function to a layer, just give its name in the activation argument.
#reference: https://www.kaggle.com/code/ryanholbrook/deep-neural-networks/tutorial

from tensorflow import keras
from keras import layers

#stacking layers into a sequential model
model = keras.Sequential([
    # the hiddent ReLU layers
    layers.Dense(units=4, activation='relu', input_shape=[2]), #two inputs into ReLU func and four output units
    layers.Dense(units=3, activation='relu'), #Relu function takes in four inputs and sent three outputs to linear output layer

    #the linear output layer
    layers.Dense(units=1), #linear output layer takes in three inputs from relu func and output 1 unit.
])

print(model.weights)
# Out:
# [<tf.Variable 'dense_71/kernel:0' shape=(2, 4) dtype=float32, numpy=
# array([[-0.23494244,  0.85856915,  0.3918481 ,  0.21298194],
#        [ 0.36011648,  0.10362172,  0.9429138 , -0.18279505]],
#       dtype=float32)>, <tf.Variable 'dense_71/bias:0' shape=(4,) dtype=float32, numpy=array([0., 0., 0., 0.], dtype=float32)>, <tf.Variable 'dense_72/kernel:0' shape=(4, 3) dtype=float32, numpy=
# array([[-0.08539069, -0.3826174 ,  0.8285545 ],
#        [-0.26411486, -0.7581436 ,  0.6955553 ],
#        [-0.86917543,  0.25641108, -0.09720671],
#        [ 0.33655918,  0.00606549, -0.55651665]], dtype=float32)>, <tf.Variable 'dense_72/bias:0' shape=(3,) dtype=float32, numpy=array([0., 0., 0.], dtype=float32)>, <tf.Variable 'dense_73/kernel:0' shape=(3, 1) dtype=float32, numpy=
# array([[-0.8369707 ],
#        [-0.63465863],
#        [ 1.0249587 ]], dtype=float32)>, <tf.Variable 'dense_73/bias:0' shape=(1,) dtype=float32, numpy=array([0.], dtype=float32)>]

# %% [markdown]
# Exercise Build deep neural networks by stacking layers inside a Sequential model
# By adding an activation func after hidden layers
# this gives the ANN the ability to learn more complex non-linear relationships in the data

# %%
#import libraries

import tensorflow as tf

#Setup plotting
import matplotlib.pyplot as plt

plt.style.use('seaborn-whitegrid')
#Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)


import pandas as pd

import pandas as pd
concrete = pd.read_csv("/content/sample_data/california_housing_test.csv")
#concrete = pd.read_csv('/content/drive/MyDrive/concrete.csv')
concrete
#concrete = pd.read_csv("ColabNotebooks/concrete.csv")
#concrete
# Out:
# <ipython-input-10-030eb6f5ba4e>:8: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# ...

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
#Great demo to show how different activation functions work

#Change activation func: relu, elu, selu, swish
activation_layer = layers.Activation('relu')

x = tf.linspace(-4.0, 4.0, 100)
y = activation_layer(x) #once createdm a layer is callable like a function

plt.figure(dpi=100) #fill 100% of plane
plt.plot(x, y)
plt.xlim(-4,4)
plt.xlabel('Input')
plt.ylabel('Output')
plt.show()
